# %%
# Dive deep into the world of McDonalds with a through analysis of their dataset, covering nutritional content, sales patterns, customer preferences, 
and much more. This analysis ailms to provide valuable into the strategies that make McDonalds a global leader in the fast-food industry

# %% [markdown]
# # Data Preprocessing:
# # Load and inspect the dataset.
# # Handle missing values and data cleaning if necessary.

# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files = os.listdir()

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.git',
#  '.gitconfig',
#  '.gk',
#  '.gnupg',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.vscode',
#  '3D Objects',
#  '5 - Python Session as on 4th Jul - Pandas',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'calender.ipynb',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'employee.json',
#  'employee.xlsx',
#  'Favorites',
#  'gitcafe',
#  'hhh.txt',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'matrix assingnment.ipynb',
#  'mc donald final capstone.ipynb',
#  'mc donald.ipynb',
#  'mc.ipynb',
#  'Mc_Donal_FInal_Capstone-Copy1.ipynb',
#  'Mc_Donal_FInal_Capstone.ipynb...........copy',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'ntuser.dat',
#  'ntuser.dat.log1',
#  'ntuser.dat.log2',
#  'ntuser.dat{70d3af96-82a4-11ef-b8a9-3c91805ff6a4}.TM.blf',
# ...

# %%
data = pd.read_csv('Nutrical Dataset.csv')

# %%
The line data = pd.read_csv('Nutrical Dataset.csv') reads the data from a CSV file called Nutrical Dataset.csv into a pandas DataFrame named data. 
This allows for further manipulation, analysis, and visualization of the dataset using pandas functions and methods.
The DataFrame will organize the file's content in a tabular format with rows and columns corresponding to the dataset.

# %%
data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
data.head(): This function displays the first five rows of the DataFrame data, providing a quick overview of the dataset's structure, including the column names and the first few entries for each column.

data.info(): This function provides a summary of the DataFrame, including the number of entries, the number of non-null values per column, the data types of each column, and memory usage. 
It helps identify missing values and understand the overall structure of the dataset.

data.describe(): This function generates descriptive statistics for the numerical columns in the DataFrame. 
It includes metrics such as count, mean, standard deviation, minimum, maximum, and quartile values, offering insights into the distribution and central tendencies of the data.

# %%
data.isnull().sum()
data.fillna(0, inplace=True)

# %%
The code checks for missing values in the DataFrame data using data.isnull().sum()
and then fills any missing values with 0 using data.fillna(0, inplace=True), ensuring no NaN values remain in the dataset.

# %%
data.drop_duplicates(inplace=True)

# %%
The code data.drop_duplicates(inplace=True) removes any duplicate rows from the DataFrame data,
ensuring that each entry in the dataset is unique by modifying the DataFrame in place.

# %%
missing_data = data.isnull().sum()
print(missing_data)
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
The code missing_data = data.isnull().sum() calculates the total number of missing (null) values for each column in
the DataFrame data and stores this information in the variable missing_data. 
The print(missing_data) statement then displays the counts of missing values for each column, allowing you to identify which columns have missing data.

# %% [markdown]
# # Exploratory Data Analysis (EDA):
# # Analyze the distribution of calorie counts across menu items.
# # Explore the nutritional content (e.g., fat, protein, carbohydrates) of different items.
# # Identify trends and patterns in the dataset.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Calories'], bins=30, kde=True)
plt.title('Distribution of Calorie Counts')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# This code visualizes the distribution of calorie values in the dataset, revealing patterns such as how many items fall within specific calorie ranges.

# %%
average_nutrition_by_category = data.groupby('Category')[['Total Fat', 'Protein', 'Carbohydrates']].mean().plot(kind='bar')
plt.title('average_nutrition_by_category')
plt.show()

# %%
data.groupby('Category')[['Calories', 'Total Fat', 'Protein']].mean()
# Out:
#                       Calories  Total Fat    Protein
# Category
# Beef & Pork         494.000000  24.866667  27.333333
# Beverages           113.703704   0.092593   1.333333
# Breakfast           526.666667  27.690476  19.857143
# Chicken & Fish      552.962963  26.962963  29.111111
# Coffee & Tea        283.894737   8.021053   8.863158
# Desserts            222.142857   7.357143   4.000000
# Salads              270.000000  11.750000  19.833333
# Smoothies & Shakes  531.428571  14.125000  10.857143
# Snacks & Sides      245.769231  10.538462   8.384615

# %% [markdown]
# # Data Visualization:
# # Create bar charts, histograms, and box plots to visualize calorie distribution and nutritional content.
# # Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).

# %%
sns.barplot(x='Category', y='Calories', data=data)
plt.title('Average Calories by Category')
plt.xticks(rotation=45)
plt.show()

sns.barplot(x='Category', y='Total Fat', data=data)
plt.title('Average Fat by Category')
plt.xticks(rotation=45)
plt.show()

sns.barplot(x='Category', y='Protein', data=data)
plt.title('Average Protein by Category')
plt.xticks(rotation=45)
plt.show()

sns.barplot(x='Category', y='Carbohydrates', data=data)
plt.title('Average Carbohydrates by Category')
plt.xticks(rotation=45)
plt.show()

# %%
nutrients = ["Protein", "Total Fat", "Carbohydrates"]
plt.figure(figsize=(10,10))
data.plot(kind="bar", x="Item", y=nutrients, stacked=True)
plt.title("Nutrient Content per Item")
plt.xlabel("items", fontsize=12)
plt.ylabel("Nutrient (grams)", fontsize=12)
plt.legend(title="Nutrient", fontsize=10)
plt.xticks(rotation=90,ha='right')
plt.show()

# %%
# This code generates a stacked bar chart displaying the nutrient content (Protein, Total Fat, Carbohydrates) for each food item. 
# The bars are stacked by nutrient type, and the x-axis shows the item names rotated 90 degrees for clarity.
# The chart includes labels, a legend, and a title, making it easy to compare nutrient values visually.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Calories', data=data)
plt.title('Calorie Distribution by Food Category')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
data = {
    'Category': ['Burgers', 'Salads', 'Desserts'],
    'Calories': [700, 400, 600],
    'Total_Fat (g)': [35, 20, 25],
    'Saturated_Fat (g)': [12, 5, 10],
    'Carbohydrates (g)': [40, 15, 70],
    'Sugars (g)': [8, 7, 50],
    'Protein (g)': [25, 10, 5],
    'Sodium (mg)': [1200, 400, 300]
}
df = pd.DataFrame(data)
print("Nutritional Comparison of Food Categories:")
print(df)
df.set_index('Category', inplace=True)
df.plot(kind='bar', figsize=(10, 7), width=0.8)
plt.title('Nutritional Comparison of Different Food Categories')
plt.xlabel('Food Categories')
plt.ylabel('Nutritional Values')
plt.xticks(rotation=0)
plt.legend(title='Nutritional Metric')
plt.tight_layout()
plt.show()
# Out:
# Nutritional Comparison of Food Categories:
#    Category  Calories  Total_Fat (g)  Saturated_Fat (g)  Carbohydrates (g)  \
# 0   Burgers       700             35                 12                 40
# 1    Salads       400             20                  5                 15
# 2  Desserts       600             25                 10                 70
#
#    Sugars (g)  Protein (g)  Sodium (mg)
# 0           8           25         1200
# 1           7           10          400
# 2          50            5          300

# %% [markdown]
# # Nutrition-Based Insights:
# # Identify menu items with the highest and lowest calorie counts.
# # Determine the average nutritional content of popular menu categories.

# %%
highest_calorie = data.loc[data['Calories'].idxmax()]
print("Highest Calorie Item:")
print(highest_calorie)
# Out:
# Highest Calorie Item:
# Category                                       Chicken & Fish
# Item                             Chicken McNuggets (40 piece)
# Serving Size                                  22.8 oz (646 g)
# Calories                                                 1880
# Calories from Fat                                        1060
# Total Fat                                               118.0
# Total Fat (% Daily Value)                                 182
# Saturated Fat                                            20.0
# Saturated Fat (% Daily Value)                             101
# Trans Fat                                                 1.0
# Cholesterol                                               265
# Cholesterol (% Daily Value)                                89
# Sodium                                                   3600
# Sodium (% Daily Value)                                    150
# Carbohydrates                                             118
# ...

# %%
lowest_calorie = data.loc[data['Calories'].idxmin()]
print("Lowest Calorie Item:")
print(lowest_calorie)
# Out:
# Lowest Calorie Item:
# Category                                 Beverages
# Item                             Diet Coke (Small)
# Serving Size                          16 fl oz cup
# Calories                                         0
# Calories from Fat                                0
# Total Fat                                      0.0
# Total Fat (% Daily Value)                        0
# Saturated Fat                                  0.0
# Saturated Fat (% Daily Value)                    0
# Trans Fat                                      0.0
# Cholesterol                                      0
# Cholesterol (% Daily Value)                      0
# Sodium                                          10
# Sodium (% Daily Value)                           0
# Carbohydrates                                    0
# Carbohydrates (% Daily Value)                    0
# Dietary Fiber                                    0
# Dietary Fiber (% Daily Value)                    0
# ...

# %%
def analyze_menu(menu_data):
    if menu_data.empty:
        return "No menu data provided."
    highest_calorie_item = menu_data.loc[menu_data["Calories"].idxmax()]
    highest_calorie_name = highest_calorie_item["Item"]
    highest_calorie_count = highest_calorie_item["Calories"]
    lowest_calorie_item = menu_data.loc[menu_data["Calories"].idxmin()]
    lowest_calorie_name = lowest_calorie_item["Item"]
    lowest_calorie_count = lowest_calorie_item["Calories"]

    return (
        f"Highest calorie item: {highest_calorie_name} ({highest_calorie_count} calories)",
        f"Lowest calorie item: {lowest_calorie_name} ({lowest_calorie_count} calories)"
    )
menu_data = pd.DataFrame({
    "Item": ["Burger", "Salad", "Chicken_McNuggets", "Pasta", "Sandwich"],
    "Description": ["Beef burger with fries", "Mixed green salad with dressing", "Cheese pizza with pepperoni", "Spaghetti with meatballs", "Chicken sandwich with cheese"],
    "Calories": [500, 150, 1880, 450, 300]
})

result = analyze_menu(menu_data)
print(result)
# Out:
# ('Highest calorie item: Chicken_McNuggets (1880 calories)', 'Lowest calorie item: Salad (150 calories)')

# %%
# This means that the highest calorie item is Chicken McNuggets with 1880 calories, and the lowest calorie item is Salad with 150 calories.

# %%
nutritional_columns = ['Calories', 'Fat', 'Carbohydrates', 'Protein']
average_nutrition_by_category = menu_data.groupby('Category')[nutritional_columns].mean()
print("Average Nutritional Content by Menu Category:")
print(average_nutrition_by_category)
import matplotlib.pyplot as plt
average_nutrition_by_category.plot(kind='bar', figsize=(12, 8))
plt.title('Average Nutritional Content by Menu Category')
plt.ylabel('Average Content (g) or (mg)')
plt.xlabel('Menu Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Average Nutritional Content by Menu Category:
#              Calories   Fat  Carbohydrates  Protein
# Category
# Main Course     512.5  27.5           45.0     25.0
# Side Dish       150.0  10.0           20.0      5.0

# %%
# The table summarizes the average nutritional content for menu categories, showing that Main Courses have higher values across all metrics, with 512.5 calories, 27.5g fat, 45.0g carbohydrates, and 25.0g protein.
# In contrast, Side Dishes are lower in nutrition, averaging 150.0 calories, 10.0g fat, 20.0g carbohydrates, and 5.0g protein.

# %%
To improve the nutritional profile of their menu, McDonald’s could implement the following strategies:

1. Increase Whole Grains and Fiber-Rich Ingredients
Incorporate whole grains: Introduce more whole-grain buns, tortillas, and bread options, which would add more fiber and nutrients compared to refined grains.
Add fiber-rich side dishes: Offering side dishes like salads with dark leafy greens, quinoa bowls, or bean-based options could significantly improve fiber intake.

2. Reduce Sodium and Sugar Content
Lower sodium: Gradually reduce the sodium content in popular items such as burgers, fries, and sauces without compromising taste. Offering low-sodium alternatives could attract health-conscious consumers.
Reduce sugar in beverages and desserts: Offer reduced-sugar versions of soft drinks, shakes, and desserts. Highlight naturally sweetened options, like fruit-based desserts, to appeal to those looking to reduce sugar intake.

3. Offer More Plant-Based and Lean Protein Options
Expand plant-based offerings: McDonald’s could offer a wider variety of plant-based burgers, wraps, and salads, made with ingredients like beans, lentils, tofu, or tempeh. These could serve as healthier, lower-fat alternatives to traditional meat-based options.
Focus on lean meats: Replace higher-fat beef patties with leaner meats like chicken, turkey, or fish. Offering grilled rather than fried options would also reduce calorie and fat content.

4. Reduce Portion Sizes and Calories
Smaller portion options: Provide smaller versions of popular items to help consumers manage calorie intake. Mini-burgers, smaller fries, and smaller drink sizes could appeal to those who want to indulge without over-consuming.
Lower-calorie meal combos: Design meal combos that are under 500 calories, incorporating items like salads, fruit sides, and water or unsweetened beverages.

5. Enhance Transparency and Education
Nutritional education: Increase transparency by providing clear, easy-to-read nutritional information on menu boards, including calorie, fat, sugar, and sodium content. Implement labeling for healthier options, and promote balanced meal combinations.
Health-conscious promotions: Highlight healthier items on the menu, including specific promotions that encourage consumers to try lower-calorie, nutrient-dense options.

6. Introduce Healthier Cooking Methods
Switch to healthier cooking oils: Using oils rich in unsaturated fats, like canola or avocado oil, could improve the overall health profile of fried items.
Air-frying technology: Offering air-fried or baked alternatives for traditionally fried foods, like chicken nuggets and fries, would reduce fat and calories without compromising on texture or flavor.

 7. Add More Fruits and Vegetables
Fruit and veggie sides: Incorporating more fruits and vegetables as standard sides, such as apple slices, baby carrots, or veggie sticks, could increase nutrient intake. Additionally, offering more vegetables in wraps, sandwiches, and salads would enhance the overall nutritional content.
Smoothies with less sugar: Introduce smoothies with more natural fruit and vegetable ingredients and less added sugar. For instance, blending greens like spinach or kale with fruits can offer nutrient-dense beverages.
By focusing on these changes, McDonald’s can not only improve the health profile of their menu but also cater to a growing segment of health-conscious consumers.
